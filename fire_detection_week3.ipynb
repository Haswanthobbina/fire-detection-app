# %%
import kagglehub

path = kagglehub.dataset_download("elmadafri/the-wildfire-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'the-wildfire-dataset' dataset.
# Path to dataset files: /kaggle/input/the-wildfire-dataset

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
  print('GPU is Available!')
else:
  print('GPU is Unavailable!')
# Out:
# GPU is Available!

# %%
train_dir = '/kaggle/input/the-wildfire-dataset/the_wildfire_dataset_2n_version/train'
val_dir = '/kaggle/input/the-wildfire-dataset/the_wildfire_dataset_2n_version/val'
test_dir = '/kaggle/input/the-wildfire-dataset/the_wildfire_dataset_2n_version/test'

# %%
classes = os.listdir(train_dir)
num_classes = len(classes)

print(f'Number of Classes: {num_classes}')
print(f'Classes: {classes}')
# Out:
# Number of Classes: 2
# Classes: ['nofire', 'fire']

# %%
plt.figure(figsize=(12, 10))
for i in range(5):
  class_path = os.path.join(train_dir, classes[0])
  img_name = os.listdir(class_path)[i]
  img_path = os.path.join(class_path, img_name)
  img = plt.imread(img_path)

  plt.subplot(1, 5, i+1)
  plt.imshow(img)
  plt.title(f'{classes[0]} \n shape: {img.shape}')
  plt.axis('off')
plt.show()

plt.figure(figsize=(12, 10))
for i in range(5):
  class_path = os.path.join(train_dir, classes[1])
  img_name = os.listdir(class_path)[i]
  img_path = os.path.join(class_path, img_name)
  img = plt.imread(img_path)

  plt.subplot(1, 5, i+1)
  plt.imshow(img)
  plt.title(f'{classes[1]} \n shape: {img.shape}')
  plt.axis('off')
plt.show()

# %%
img_width, img_height = 150, 150
batch_size = 32

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = 'binary',
    shuffle = True
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = 'binary',
    shuffle = True
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = 'binary',
    shuffle = True
)
# Out:
# Found 1887 images belonging to 2 classes.
# Found 402 images belonging to 2 classes.
# Found 410 images belonging to 2 classes.

# %%
class_mapping = train_generator.class_indices
class_names = list(class_mapping.keys())
print("Class Names:", class_names)
# Out:
# Class Names: ['fire', 'nofire']

# %%
model = Sequential([
    Input(shape=(img_width, img_height, 3)),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
]
)

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    18,940,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,034,177 (72.61 MB)
#  Trainable params: 19,034,177 (72.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# train the model
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    epochs = 12,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/12
# 12/58 ━━━━━━━━━━━━━━━━━━━━ 5:06 7s/step - accuracy: 0.5593 - loss: 1.2487
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (104688771 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 37/58 ━━━━━━━━━━━━━━━━━━━━ 2:27 7s/step - accuracy: 0.6023 - loss: 0.9636
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (89747104 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.6237 - loss: 0.8657
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 526s 9s/step - accuracy: 0.6246 - loss: 0.8622 - val_accuracy: 0.7318 - val_loss: 0.4994
# Epoch 2/12
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.7812 - loss: 0.4299
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7812 - loss: 0.4299 - val_accuracy: 0.7578 - val_loss: 0.5046
# Epoch 3/12
# 23/58 ━━━━━━━━━━━━━━━━━━━━ 3:38 6s/step - accuracy: 0.7477 - loss: 0.4869
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (104688771 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 38/58 ━━━━━━━━━━━━━━━━━━━━ 2:11 7s/step - accuracy: 0.7574 - loss: 0.4781
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (89747104 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 462s 8s/step - accuracy: 0.7637 - loss: 0.4761 - val_accuracy: 0.7109 - val_loss: 0.5129
# Epoch 4/12
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.7812 - loss: 0.5025 - val_accuracy: 0.6719 - val_loss: 0.5907
# Epoch 5/12
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 502s 9s/step - accuracy: 0.7518 - loss: 0.5031 - val_accuracy: 0.7760 - val_loss: 0.4667
# Epoch 6/12
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.7812 - loss: 0.5636
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.7812 - loss: 0.5636 - val_accuracy: 0.7656 - val_loss: 0.4527
# Epoch 7/12
# 14/58 ━━━━━━━━━━━━━━━━━━━━ 4:37 6s/step - accuracy: 0.8190 - loss: 0.4122
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (89747104 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 24/58 ━━━━━━━━━━━━━━━━━━━━ 3:32 6s/step - accuracy: 0.8077 - loss: 0.4321
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (104688771 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 453s 8s/step - accuracy: 0.7895 - loss: 0.4568 - val_accuracy: 0.7734 - val_loss: 0.4398
# Epoch 8/12
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.7500 - loss: 0.5048
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.7500 - loss: 0.5048 - val_accuracy: 0.7943 - val_loss: 0.4319
# Epoch 9/12
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 35:31 37s/step - accuracy: 0.8438 - loss: 0.3296
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (104688771 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 22/58 ━━━━━━━━━━━━━━━━━━━━ 3:55 7s/step - accuracy: 0.8007 - loss: 0.4252
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (89747104 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 486s 8s/step - accuracy: 0.8011 - loss: 0.4449 - val_accuracy: 0.7266 - val_loss: 0.4947
# Epoch 10/12
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6875 - loss: 0.5143
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.6875 - loss: 0.5143 - val_accuracy: 0.7500 - val_loss: 0.4907
# Epoch 11/12
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 452s 8s/step - accuracy: 0.8002 - loss: 0.4454 - val_accuracy: 0.8203 - val_loss: 0.4261
# Epoch 12/12
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.7188 - loss: 0.5935 - val_accuracy: 0.8047 - val_loss: 0.4407

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  3/12 ━━━━━━━━━━━━━━━━━━━━ 1:08 8s/step - accuracy: 0.8542 - loss: 0.3884
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (101859328 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#  6/12 ━━━━━━━━━━━━━━━━━━━━ 46s 8s/step - accuracy: 0.8336 - loss: 0.4104
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (94487082 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 7s 8s/step - accuracy: 0.8141 - loss: 0.4344
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:3452: DecompressionBombWarning: Image size (96631920 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 98s 8s/step - accuracy: 0.8127 - loss: 0.4353
# Test Accuracy: 0.8047

# %%
model.save('FFD.keras')

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# Load the model
model = load_model('FFD.keras')

# Predict on new image - create a function
def predict_fire(img_path):
  img = image.load_img(img_path, target_size=(150, 150))
  img_array = image.img_to_array(img)
  img_array = np.expand_dims(img_array, axis=0)
  img_array /= 255.0

  prediction = model.predict(img_array)
  if prediction[0] > 0.5:
    predicted_class = class_names[1]
  else:
    predicted_class = class_names[0]

  plt.imshow(img)
  plt.title(f'Predicted: {predicted_class}')
  plt.axis('off')
  plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 12 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
os.listdir('/kaggle/input/the-wildfire-dataset/the_wildfire_dataset_2n_version/test/fire')
# Out:
# ['29071683967_b1ed99cb89_o.jpg',
#  '9570772331_0822c9b670_o.jpg',
#  'malachi-brooks-lhZ61YqYhnA-unsplash.jpg',
#  '28537699003_1a422593ca_o.jpg',
#  '51404893429_95e004cb03_o.jpg',
#  '26131736898_9e6a8cd68f_o.jpg',
#  '50622961901_b344261876_o.jpg',
#  '35410741240_4dde737981_o.jpg',
#  '20960888741_8c4be2c1df_o.jpg',
#  '52230132421_efbcf13fe2_o.png',
#  '52291063924_0a29bb857f_o.jpg',
#  '9600858470_9d349a2271_o.jpg',
#  '52390706166_2ef8a61765_o.jpg',
#  '37342470222_39ab7a0005_o.jpg',
#  '19196558588_267f24b847_o.jpg',
#  '50622019883_c988dcf6ba_o.jpg',
#  '33116128054_0169df2131_o.jpg',
#  '32923781413_197187fc02_o.jpg',
#  '50380847162_24a484981b_o.jpg',
#  '52561565423_bbc7b2daf8_o.jpg',
#  '27389369514_cd30397ac2_o.jpg',
#  '51339519791_6c87189d8b_o.jpg',
#  '26549039025_b4cce14ec7_o.jpg',
#  '51840740529_300582b71b_o.jpg',
#  '36171933842_96ffbd3205_o.jpg',
#  '51236039150_95c87d9260_o.jpg',
#  '8469662828_371dbcb70d_o.jpg',
#  '52871185823_2561dcb25a_o.jpg',
#  '28347651877_ce21ed134e_o.png',
#  '35436611810_9b938fc10c_o.jpg',
#  'malachi-brooks-44Kg_VToFzU-unsplash.jpg',
#  '51341732084_4bb62bfa4c_o.jpg',
#  '27002088114_aa5cc7f353_o.jpg',
#  'matt-palmer-qmFU0516eAk-unsplash.jpg',
#  '50380652301_a49c4c245b_o.jpg',
#  '50323624771_c50229c6f9_o.jpg',
#  '53080010483_005d9f15a9_o.jpg',
#  '35784580196_cb15962e4e_o.jpg',
#  '50331586642_e1f77b7c27_o.jpg',
#  '9598063779_5a497ff60e_o.jpg',
#  '35531882843_042b0075e7_o.jpg',
#  '36204002431_91b77a7dc5_o.jpg',
#  '50380846762_05de20fe60_o.jpg',
#  '52036933602_3e5592af75_o.jpg',
#  '50237377031_208e2379f2_o.jpg',
#  '29217093202_705f9dda46_o.jpg',
#  '52466779720_f12b1c76f8_o.jpg',
#  '29050868872_a81cc9e411_o.jpg',
#  '48250134737_d2cd909008_o.jpg',
#  'michael-chacon-wRw3L6hwB2E-unsplash.jpg',
#  '8469663002_0ee1993038_o.jpg',
#  '51839424127_49f8e61656_o.jpg',
#  '46580252795_53d18db27b_o.jpg',
#  '28839451467_99ba52a28b_o.jpg',
#  '27968020506_5f1a59f2a5_o.jpg',
#  '28809454424_c694988115_o.jpg',
#  '30227808988_2cd8f53145_o.jpg',
#  '52390588912_3c6e5f2f67_o.jpg',
#  '52465192596_bdd7f52f1c_o.png',
#  '51840740734_ef14b3e4dd_o.jpg',
#  '43145068490_8263ca98d9_o.jpg',
#  '28431967367_37bc44b0c1_o.jpg',
#  '51785682491_8b035b8bbb_o.jpg',
#  '35531872313_eb8772df72_o.jpg',
#  '50245909001_e383b539af_o.jpg',
#  '37342469502_36f0ec280c_o.jpg',
#  '50237932316_549109d674_o.jpg',
#  '9573557452_dfb9664b2f_o.jpg',
#  'norman-meyer-tai1cTT5eX0-unsplash.jpg',
#  '52374364783_31f068752b_o.jpg',
#  '52304531978_24c1bbebcf_o.png',
#  '45972183211_9a67172c34_o.jpg',
#  '52293502090_77032c6be0_o.jpg',
#  '29431355988_ba5c97c131_o.jpg',
#  '52258839816_bbb2d7b2ac_o.jpg',
#  '41094811384_1382be1721_o.jpg',
#  '52297292176_94a7486256_o.jpg',
#  '29123316786_b55ae67b44_o.jpg',
#  'matt-palmer-kbTp7dBzHyY-unsplash.jpg',
#  '41816155542_df8bf25a37_o.jpg',
#  '52106050158_5ef7a57835_o.jpg',
#  '36891202290_e559c37e66_o.jpg',
#  'malachi-brooks-QFa3PaR5aos-unsplash.jpg',
#  '52224745932_9f43b81b98_o.jpg',
#  '51840740744_6b8646f329_o.jpg',
#  '28020330864_d7a2429a7e_o.jpg',
#  '52230401409_3653f5cf3b_o.png',
#  '36296148516_0a2b440e28_o.jpg',
#  '35410488130_9455032ce9_o.jpg',
#  '52290801988_c24208ebc2_o.jpg',
#  '50293973463_065aaf4378_o.jpg',
#  '51284080730_6ab71a3862_o.jpg',
#  '50575966873_8cef16dcc6_o.jpg',
#  '51233526390_1d23dbc6b5_o.jpg',
#  '33352231150_03c54e5e9b_o.jpg',
#  '52465911062_9046fcbb0f_o.jpg',
#  '28431976467_0ff1af4b17_o.jpg',
#  '51841108815_6d296388af_o.jpg',
#  '34025009332_4229aabd8d_o.jpg',
#  '52293015808_1e4f9d5b0a_o.jpg',
#  '52178171048_d3745e41da_o.jpg',
#  '50238074027_f2473f2d8a_o.jpg',
#  '52573687964_c448942429_o.jpg',
#  '52227794918_250e3e0ba6_o.jpg',
#  '50245620368_2f03cf7055_o.jpg',
#  '50322960443_27d53066ce_o.jpg',
#  '51306907748_6e28024e7d_o.jpg',
#  '36171982712_d1839b35aa_o.jpg',
#  '37325108026_bb99689e1f_o.jpg',
#  '45922878832_c4755cc402_o.jpg',
#  '35436556160_7c7c9ab2b2_o.jpg',
#  '50321123752_d1ae13455a_o.jpg',
#  '35410492380_c881508ce7_o.jpg',
#  '50517815882_2959039cc0_o.jpg',
#  '34549858860_4a9183e9af_o.jpg',
#  '50229336772_7f5719786b_o.jpg',
#  '48250059981_62acdb5742_o.jpg',
#  '52871129020_848fde461c_o.jpg',
#  '34823336661_82a258fa12_o.jpg',
#  '52290796314_c886e9fd0e_o.jpg',
#  '42582898944_13a64c057f_o.jpg',
#  '42286648270_e517db94be_o.jpg',
#  '48690175756_6a3aca7c53_o.jpg',
#  '52289825127_2e4869a883_o.jpg',
#  '52466691809_7b709ba3af_o.jpg',
#  '52573007327_cc6dfd6afe_o.jpg',
#  '50517815722_17ae2240d2_o.jpg',
#  '52224774932_ea3e1aca55_o.jpg',
#  '27335331950_39b376eddd_o.jpg',
#  '34957472404_14d39d5c12_o.jpg',
#  '52530238331_60e6ced567_o.jpg',
#  '45642971861_abbca24c56_o.jpg',
#  '52391937615_5103401805_o.jpg',
#  '52530147676_f293f65c1d_o.jpg',
#  '8468567451_a6900fa875_o.jpg',
#  '28811952773_710e9d2d23_o.jpg',
#  '33100052071_1903ff386b_o.jpg',
#  '36171934502_d220ec0b90_o.jpg',
#  '42818488645_1588e3fc8d_o.jpg',
#  '52231247312_2442b7ef01_o.jpg',
#  '52225751111_53c7f3b819_o.jpg',
#  '37342469552_ca9891fdd5_o.jpg',
#  '8468567365_18760a6d8b_o.jpg',
#  '34984770664_84f9f5cc6c_o.jpg',
#  '51685793514_6fa6a94347_o.jpg',
#  '35015024723_7500837d08_o.jpg',
#  '28431975607_7fc4cc466c_o.jpg',
#  '50408559278_10f041ed61_o.jpg',
#  '43772086021_c501debc58_o.jpg',
#  '27951228213_2dd961ac1f_o.jpg',
#  '50622843556_679c9aec75_o.jpg',
#  '44629829372_5916777e44_o.jpg',
#  '32923774463_8a894851d1_o.jpg',
#  '9573568070_ec00ce554d_o.jpg',
#  '28528946360_5254cdafba_o.jpg',
#  '52925330921_787d02fcd0_o.jpg',
#  '52224743582_c267792d90_o.jpg',
#  '50321143652_b8f0cefa95_o.jpg',
#  '41870900650_fb240bb4ac_o.jpg']

# %%
predict_fire('/kaggle/input/the-wildfire-dataset/the_wildfire_dataset_2n_version/test/fire/27002088114_aa5cc7f353_o.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# Assuming 'model' is your trained TensorFlow Keras model
#model.save('my_tensorflow_model.h5')

# You can also save in the native Keras format (recommended)
model.save('my_tensorflow_model.keras')

# %%
# !cp FFD.keras /content/
# Out:
# cp: 'FFD.keras' and '/content/FFD.keras' are the same file

# %%
st.header("Upload an image to predict")

uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    image_to_predict = Image.open(uploaded_file)
    st.image(image_to_predict, caption='Uploaded Image.', use_column_width=True)
    st.write("")
    st.write("Classifying...")

    # Make prediction
    predicted_class = predict_fire(image_to_predict)

    st.write(f"Prediction: {predicted_class}")

# %%
# Function to make predictions
def predict_fire(img):
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0

    prediction = model.predict(img_array)
    if prediction[0] > 0.5:
        predicted_class = class_names[1]
    else:
        predicted_class = class_names[0]

    return predicted_class

# %%
# !ls -l
# Out:
# total 669328
# drwx------ 5 root root      4096 Oct 18 12:54 drive
# -rw-r--r-- 1 root root 228457147 Oct 18 13:00 FFD.keras
# -rw-r--r-- 1 root root 228458584 Oct 18 12:56 my_tensorflow_model.h5
# -rw-r--r-- 1 root root 228457147 Oct 18 12:56 my_tensorflow_model.keras
# drwxr-xr-x 1 root root      4096 Oct 16 13:41 sample_data
